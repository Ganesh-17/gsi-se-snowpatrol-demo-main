# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %aimport
# Out:
# Modules to reload:
# all-except-skipped
#
# Modules to skip:

# %%
import json
from snowflake.snowpark.session import Session
import snowflake.snowpark.functions as F
import snowflake.snowpark.types as T
from dotenv import find_dotenv
from pathlib import Path
import sys

project_home1 = Path(find_dotenv()).parent
sys.path.append(str(project_home1))

from constants1 import *

# %% [markdown]
# ## Data Pipline

# %% [markdown]
# ### Snowpark Session

# %%
with open(project_home1 / 'config/creds.json', 'r') as ff:
    conn_param=json.load(ff)

session = Session.builder.configs(conn_param).create()

# %% [markdown]
# ### Database, Schema & resource creation

# %%
session.sql(f"create database if not exists {SNOWPATROL_DB}").collect()
session.sql(f"create schema if not exists {SNOWPATROL_DB}.{DEVOPS_SH}").collect()
session.sql(f"create stage if not exists {SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}").collect()
session.sql(f"create stage if not exists {SNOWPATROL_DB}.{DEVOPS_SH}.{DEPS_STAGE}").collect()
session.sql(f"create stage if not exists {SNOWPATROL_DB}.{DEVOPS_SH}.{MODELS_STAGE}").collect()
session.sql(f"create stage if not exists {SNOWPATROL_DB}.{DEVOPS_SH}.{OBJECT_STAGE}").collect()

# This File Format uses a special option available for CSV schema inference
session.sql(f"create file format if not exists {SNOWPATROL_DB}.{DEVOPS_SH}.ff_csv_with_header type=CSV parse_header=TRUE field_optionally_enclosed_by='\"'").collect()
# Out:
# [Row(status='File format FF_CSV_WITH_HEADER successfully created.')]

# %% [markdown]
# ### Sample data upload

# %%
data_dir = project_home1 / "data1" 
session.sql(f"PUT file://{project_home1}/data1/obfuscated/* @{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE} overwrite=True auto_compress=True").collect()
session.sql(f"PUT file://{project_home1}/data1/generated/whitelisted_users.csv @{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE} overwrite=True auto_compress=True").collect()
session.sql(f"PUT file://{project_home1}/data1/generated/sample_okta_logs.csv @{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE} overwrite=True auto_compress=True").collect()
session.sql(f"PUT file://{project_home1}/data1/generated/monitored_apps.csv @{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE} overwrite=True auto_compress=True").collect()
# Out:
# [Row(source='monitored_apps.csv', target='monitored_apps.csv.gz', source_size=86, target_size=128, source_compression='NONE', target_compression='GZIP', status='UPLOADED', message='')]

# %%
session.sql(f"PUT file://{project_home1}/Src1/python/snowpatrol/train1.py @{SNOWPATROL_DB}.{DEVOPS_SH}.{DEPS_STAGE} overwrite=True auto_compress=False").collect()
session.sql(f"PUT file://{project_home1}/Src1/python/snowpatrol/constants1.py @{SNOWPATROL_DB}.{DEVOPS_SH}.{DEPS_STAGE} overwrite=True auto_compress=False").collect()
# Out:
# [Row(source='constants1.py', target='constants1.py', source_size=567, target_size=576, source_compression='NONE', target_compression='NONE', status='UPLOADED', message='')]

# %% [markdown]
# ### Table creation to hold source data - FP data
#
# > Note: Uses Schema detection on CSV

# %%
session.sql(
    f"""
    CREATE TABLE IF NOT EXISTS {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_MONITORED_APPS}
    USING TEMPLATE (
    SELECT ARRAY_AGG(OBJECT_CONSTRUCT(*))
      FROM TABLE(
        INFER_SCHEMA(
          LOCATION=>'@{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}/monitored_apps.csv',
          FILE_FORMAT=>'snowpatrol.MAIN.ff_csv_with_header',
          IGNORE_CASE => TRUE
        )
      ))
    """
).collect()

session.sql(
    f"""
    CREATE TABLE IF NOT EXISTS {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_OKTA_USERS}
    USING TEMPLATE (
    SELECT ARRAY_AGG(OBJECT_CONSTRUCT(*))
      FROM TABLE(
        INFER_SCHEMA(
          LOCATION=>'@{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}/sample_okta_logs.csv',
          FILE_FORMAT=>'snowpatrol.MAIN.ff_csv_with_header',
          IGNORE_CASE => TRUE
        )
      ))
    """
).collect()

session.sql(
    f"""
    CREATE TABLE IF NOT EXISTS {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_APP_LOGS}
    USING TEMPLATE (
    SELECT ARRAY_AGG(OBJECT_CONSTRUCT(*))
      FROM TABLE(
        INFER_SCHEMA(
          LOCATION=>'@{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}/SnowPatrol_validation_data_app1 _.csv',
          FILE_FORMAT=>'snowpatrol.MAIN.ff_csv_with_header',
          IGNORE_CASE => TRUE
        )
      ))
    """
).collect()


session.sql(
    f"""
    CREATE TABLE IF NOT EXISTS {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_WORK_DAYS}
    USING TEMPLATE (
    SELECT ARRAY_AGG(OBJECT_CONSTRUCT(*))
      FROM TABLE(
        INFER_SCHEMA(
          LOCATION=>'@{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}/SnowPatrol_Working_Days.csv',
          FILE_FORMAT=>'snowpatrol.MAIN.ff_csv_with_header',
          IGNORE_CASE => TRUE
        )
      ))
    """
).collect()

session.sql(
    f"""
    CREATE TABLE IF NOT EXISTS {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_EMP_METADATA}
    USING TEMPLATE (
    SELECT ARRAY_AGG(OBJECT_CONSTRUCT(*))
      FROM TABLE(
        INFER_SCHEMA(
          LOCATION=>'@{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}/SnowPatrol_validation_emp_details_app1.csv',
          FILE_FORMAT=>'snowpatrol.MAIN.ff_csv_with_header',
          IGNORE_CASE => TRUE
        )
      ))
    """
).collect()

session.sql(
    f"""
    CREATE TABLE IF NOT EXISTS {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_WHITELISTED_USERS}
    USING TEMPLATE (
    SELECT ARRAY_AGG(OBJECT_CONSTRUCT(*))
      FROM TABLE(
        INFER_SCHEMA(
          LOCATION=>'@{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}/whitelisted_users.csv',
          FILE_FORMAT=>'snowpatrol.MAIN.ff_csv_with_header',
          IGNORE_CASE => TRUE
        )
      ))
    """
).collect()
# Out:
# [Row(status='Table WHITELISTED_USERS successfully created.')]

# %% [markdown]
# ### Copying data into respective source tables

# %%
session.sql(f"TRUNCATE TABLE {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_MONITORED_APPS}").collect()
session.sql(
    f""" 
    copy into {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_MONITORED_APPS}
    from @{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}
    files = ('monitored_apps.csv.gz') 
    file_format = (type = CSV skip_header=1 field_optionally_enclosed_by='"')
""").collect()

session.sql(f"TRUNCATE TABLE {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_OKTA_USERS}").collect()
session.sql(
    f""" 
    copy into {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_OKTA_USERS}
    from @{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}
    files = ('sample_okta_logs.csv.gz') 
    file_format = (type = CSV skip_header=1 field_optionally_enclosed_by='"')
""").collect()

session.sql(f"TRUNCATE TABLE {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_APP_LOGS}").collect()

session.sql(
    f""" 
    copy into {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_APP_LOGS}
    from @{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}
    files = ('SnowPatrol_validation_data_app1 _.csv.gz','SnowPatrol_validation_data_app2 _.csv.gz','SnowPatrol_validation_data_app3 _.csv.gz','SnowPatrol_validation_data_app4 _.csv.gz')
    file_format = (type = CSV skip_header=1 field_optionally_enclosed_by='"')
""").collect()

# Sample work days table - company schedule of whether each day is a work day or not
session.sql(f"TRUNCATE TABLE {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_WORK_DAYS}").collect()

session.sql(
    f""" 
    copy into {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_WORK_DAYS}
    from @{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}
    files = ('SnowPatrol_Working_Days.csv.gz')
    file_format = (type = CSV skip_header=1 field_optionally_enclosed_by='"')
""").collect()

session.sql(f"TRUNCATE TABLE {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_EMP_METADATA}").collect()

session.sql(
    f""" 
    copy into {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_EMP_METADATA}
    from @{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}
    files = ('SnowPatrol_validation_emp_details_app1.csv.gz','SnowPatrol_validation_emp_details_app2.csv.gz','SnowPatrol_validation_emp_details_app3.csv.gz','SnowPatrol_validation_emp_details_app4.csv.gz')
    file_format = (type = CSV skip_header=1 field_optionally_enclosed_by='"')
    ON_ERROR="CONTINUE"
""").collect()

session.sql(
    f""" 
    copy into {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_WHITELISTED_USERS}
    from @{SNOWPATROL_DB}.{DEVOPS_SH}.{DATA_STAGE}
    files = ('whitelisted_users.csv.gz') 
    file_format = (type = CSV skip_header=1 field_optionally_enclosed_by='"')
""").collect()
# Out:
# [Row(file='data/whitelisted_users.csv.gz', status='LOADED', rows_parsed=1, rows_loaded=1, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]

# %%
# import pandas as pd
# Data=session.sql(f"""select e.session_user,a.snapshot_datetime from                                     
# {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_EMP_METADATA} e,{SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_APP_LOGS} a 
# where a.snapshot_datetime <= '08/04/2023' and e.session_user=a.session_user""").to_pandas()
# #Data1=pd.DataFrame(Data)

# %%
# Data

# %%
#%store Data1

# %%
#my code
import pandas as pd
a=session.sql(f""" select (SESSION_USER) from {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_EMP_METADATA}""").collect()
a1=pd.DataFrame(a)

# %%
a1
# Out:
#                           SESSION_USER
# 0    dhamodharan.balamani@anblicks.com
# 1            nishant.shah@anblicks.com
# 2            devang.patel@anblicks.com
# 3             manoj.kumar@anblicks.com
# 4       gowtham.voruganti@anblicks.com
# ..                                 ...
# 700             fuad.nour@anblicks.com
# 701            ip-service@anblicks.com
# 702         pradeep.kollu@anblicks.com
# 703          shani.jangid@anblicks.com
# 704          sumera.jaggi@anblicks.com
#
# [705 rows x 1 columns]

# %%
len(a1)
# Out:
# 705

# %%
email=[]
count=0
for i in range(len(a1)):
    #print (a1['SESSION_USER'][i])
    count=count+1
    email.append(a1['SESSION_USER'][i])
print(count)
# Out:
# 705

# %%
email
# Out:
# ['dhamodharan.balamani@anblicks.com',
#  'nishant.shah@anblicks.com',
#  'devang.patel@anblicks.com',
#  'manoj.kumar@anblicks.com',
#  'gowtham.voruganti@anblicks.com',
#  'pranshu.joshi@anblicks.com',
#  'kotapati.saitha@anblicks.com',
#  'rasi.konatham@anblicks.com',
#  'samir.bhatt@anblicks.com',
#  'munwar@anblicks.com',
#  'abishek.kunduru@anblicks.com',
#  'lalitha.nasina@anblicks.com',
#  'sandeep.nidumukkala@anblicks.com',
#  'gaurav.patel@anblicks.com',
#  'geetanjali.dash@anblicks.com',
#  'sajja.ratnasravya@anblicks.com',
#  'vijay.diwakar@anblicks.com',
#  'ankit.patel@anblicks.com',
#  'vinay.gundavaram@anblicks.com',
#  'purvesh.kachhiya@anblicks.com',
#  'abhilash.p@anblicks.com',
#  'raja.seeni@anblicks.com',
#  'mitesh.gajjar@anblicks.com',
#  'bansilal.keloth@anblicks.com',
#  'nikunj.ranpura@anblicks.com',
#  'jaimin.patel@anblicks.com',
#  'ronak.padhya@anblicks.com',
#  'nilesh.jain@anblicks.com',
#  'hardik.sanghani@anblicks.com',
#  'deepika.mudiyala@anblicks.com',
#  'santosh.yadav@anblicks.com',
#  'abhishek.makhija@anblicks.com',
#  'durgavikesh.pulapa@anblicks.com',
#  'sireesha.alavala@anblicks.com',
#  'praveenkumar.macha@anblicks.com',
#  'rithesh.gummerla@anblicks.com',
#  'ganeshcharan.p@anblicks.com',
#  'manasa.jonnadula@anblicks.com',
#  'saikiran.p@anblicks.com',
#  'mounika.koduru@anblicks.com',
#  'surender.thanneeru@anblicks.com',
#  'kiran.kumar@anblicks.com',
#  'akhila.madduri@anblicks.com',
#  'divya.matsa@anblicks.com',
#  'saeeda.rushnaiwala@anblicks.com',
#  'srisai.maddukuri@anblicks.com',
#  'rehman.shaik@anblicks.com',
#  'uhapriya.akunuri@anblicks.com',
#  'pavani.pasupulati@anblicks.com',
#  'rajasekharreddy.g@anblicks.com',
#  'sravan.m@anblicks.com',
#  'rahul.ojha@anblicks.com',
#  'bharath.rudra@anblicks.com',
#  'dhaval.raval@anblicks.com',
#  'sudharani.b@anblicks.com',
#  'aashutosh.makwana@anblicks.com',
#  'naresh.chillur@anblicks.com',
#  'harsh.patel@anblicks.com',
#  'sagar.katariya@anblicks.com',
#  'rushika.shah@anblicks.com',
#  'shravani.bathula@anblicks.com',
#  'manohar.gajengi@anblicks.com',
#  'saisrinivas.chinta@anblicks.com',
#  'deepthi.rayapati@anblicks.com',
#  'prapti.patel@anblicks.com',
#  'vijay.makwana@anblicks.com',
#  'krunal.rami@anblicks.com',
#  'raj.sindal@anblicks.com',
#  'saisyam.dampuri@anblicks.com',
#  'nagaarvind.adari@anblicks.com',
#  'lokeshwar.chankapure@anblicks.com',
#  'shiva.nallavelli@anblicks.com',
#  'tejaswini.kolla@anblicks.com',
#  'vasanth.kandagatla@anblicks.com',
#  'harsha.nadendla@anblicks.com',
#  'haribabu.thamatam@anblicks.com',
#  'abhinav.chelluri@anblicks.com',
#  'ramesh.talamala@anblicks.com',
#  'pavan.muniganti@anblicks.com',
#  'akhila.siripurapu@anblicks.com',
#  'nitya.sripati@anblicks.com',
#  'vishvak.tatineni@anblicks.com',
#  'lance.lugo@datalinksoftware.com',
#  'madhumitha.kuna@anblicks.com',
#  'Vinay.Beeravolu@datalinksoftware.com',
#  'John.Hargett@datalinksoftware.com',
#  'Logan.Galler@datalinksoftware.com',
#  'Kenneth.Harper@datalinksoftware.com',
#  'chintan.mehta@anblicks.com',
#  'it@anblicks.com',
#  '___@anblicks.onmicrosoft.com',
#  'aakansha.jain@anblicks.com',
#  'aashutosh.makwana@anblicks.com',
#  'aayushi.soni@anblicks.com',
#  'abhilash.p@anblicks.com',
#  'abhinav.chelluri@anblicks.com',
#  'abhinav.muvva@anblicks.com',
#  'abhishek.makhija@anblicks.com',
#  'abhishek.singh@anblicks.com',
#  'abhishek.vadnagra@anblicks.com',
#  'abishek.kunduru@anblicks.com',
#  'aditya.jain@anblicks.com',
#  'admin@anblicks.com',
#  'ahm.reception@anblicks.com',
#  'ajaychand.b@anblicks.com',
#  'saiakhil.gollamudi@anblicks.com',
#  'akhila.madduri@anblicks.com',
#  'akshar.bhalodia@anblicks.com',
#  'akshat.patel@anblicks.com',
#  'akshitha.veesam@anblicks.com',
#  'alan.parker@anblicks.com',
#  'albert.manoj@anblicks.com',
#  'alerts@anblicks.com',
#  'aman.dhillon@anblicks.com',
#  'amij.patel@anblicks.com',
#  'amit@anblicks.com',
#  'amit.maru@anblicks.com',
#  'amit.somaru@anblicks.com',
#  'anand.gangapuram@anblicks.com',
#  'anand.k@anblicks.com',
#  'anand.maheshwari@anblicks.com',
#  'anandvardhan.pandi@anblicks.com',
#  'ananth.thuluva@anblicks.com',
#  'Accounting@anblicks.com',
#  'anblicksdallas@anblicks.com',
#  'anblicks-HR@anblicks.com',
#  'aneneosa.isichei@anblicks.com',
#  'anil.bitra@anblicks.com',
#  'Anil.Makineni_DATALINKSOFTWARE.COM#EXT#@anblicks.onmicrosoft.com',
#  'anita.anderson@anblicks.com',
#  'anjaneyulu.m@anblicks.com',
#  'ankit.amin@anblicks.com',
#  'ankit.k@anblicks.com',
#  'ankit.mahatma@anblicks.com',
#  'ankit.patel@anblicks.com',
#  'ankitha.chigurupati@anblicks.com',
#  'annual.event@anblicks.com',
#  'anuradha.mandala@anblicks.com',
#  'anubhav.rai@anblicks.com',
#  'anurag.gupta@anblicks.com',
#  'anusha.nandam@anblicks.com',
#  'anushree.mahajan@anblicks.com',
#  'anvesh.karre@anblicks.com',
#  'apeksha.chawan@anblicks.com',
#  'aravind.kothagadi@anblicks.com',
#  'arjun.g@anblicks.com',
#  'arkan.malek@anblicks.com',
#  'nagaarvind.adari@anblicks.com',
#  'arvind.prasad@anblicks.com',
#  'ashequs.samad@anblicks.com',
#  'ashish.patel@anblicks.com',
#  'ashish.shah@anblicks.com',
#  'ashish.sinha@anblicks.com',
#  'ashish.vanjarapu@anblicks.com',
#  'ashok.eeday@anblicks.com',
#  'ashok.pothureddy@anblicks.com',
#  'ashritha.kanukula@anblicks.com',
#  'ashwin.gonnabhaktula@anblicks.com',
#  'astha.agrawal@anblicks.com',
#  'Auditor@anblicks.com',
#  'Auditor1@anblicks.com',
#  'avadh.patel@anblicks.com',
#  'avinash.chinta@anblicks.com',
#  'ayeshashaik@anblicks.com',
#  'azure.billing@anblicks.com',
#  'bansilal.keloth@anblicks.com',
#  'bayya.vuragayala@anblicks.com',
#  'bhagya.talabattula@anblicks.com',
#  'bhagyesh.bhut@anblicks.com',
#  'bharat.gauli@anblicks.com',
#  'bharatsinh.parmar@anblicks.com',
#  'bharathreddy.gali@anblicks.com',
#  'saibharath.maradani@anblicks.com',
#  'bharath.pogula@anblicks.com',
#  'bharath.rudra@anblicks.com',
#  'bharath.sudini@anblicks.com',
#  'bharati.kandukuri@anblicks.com',
#  'bhargava.buchipally@anblicks.com',
#  'bhargavi.gogulamudi@anblicks.com',
#  'bhavana.vunyala@anblicks.com',
#  'bhavin.bhavsar@anblicks.com',
#  'bhumika.adhia@anblicks.com',
#  'bhushan.sambhus@anblicks.com',
#  'himabindhu.ogirala@anblicks.com',
#  'brahmaiah.vallabhuni@anblicks.com',
#  'brahmeswara.donepudi@anblicks.com',
#  'brijesh.amrutiya@anblicks.com',
#  'chaitanya@anblicks.com',
#  'chamundeswar.b@anblicks.com',
#  'chandana.kundeti@anblicks.com',
#  'harika.pedapudi@anblicks.com',
#  'navya.chalapati@anblicks.com',
#  'amij.patel@anblicks.com',
#  'aayushi.soni@anblicks.com',
#  'krunal.vyas@anblicks.com',
#  'dhamodharan.balamani@anblicks.com',
#  'avadh.patel@anblicks.com',
#  'madhu@anblicks.com',
#  'swetha.appisetty@anblicks.com',
#  'abhishek.singh@anblicks.com',
#  'anand.k@anblicks.com',
#  'saikiran.b@anblicks.com',
#  'mujtaba@anblicks.com',
#  'fayaz@anblicks.com',
#  'devisri.desu@anblicks.com',
#  'saiakhil.gollamudi@anblicks.com',
#  'lalitha.ginjupalli@anblicks.com',
#  'komal.saini@anblicks.com',
#  'reethika.kolusu@anblicks.com',
#  'kavyasree.kommaraju@anblicks.com',
#  'keerthana.medakayala@anblicks.com',
#  'jyothi.vuyyuru@anblicks.com',
#  'ganeshkasyap.movva@anblicks.com',
#  'rohith.velpula@anblicks.com',
#  'naveen.bandaru@anblicks.com',
#  'divya.gunde@anblicks.com',
#  'likhitha.sunkara@anblicks.com',
#  'tejaprasad.pampana@anblicks.com',
#  'ashish.vanjarapu@anblicks.com',
#  'sana.shaik@anblicks.com',
#  'bhargavi.gogulamudi@anblicks.com',
#  'nishilatha.kaile@anblicks.com',
#  'ashok.pothureddy@anblicks.com',
#  'nishant.shah@anblicks.com',
#  'devang.patel@anblicks.com',
#  'manoj.kumar@anblicks.com',
#  'gowtham.voruganti@anblicks.com',
#  'swetha.s@anblicks.com',
#  'pranshu.joshi@anblicks.com',
#  'harihara.b@anblicks.com',
#  'kotapati.saitha@anblicks.com',
#  'rasi.konatham@anblicks.com',
#  'ganesh.kancharla@anblicks.com',
#  'samir.bhatt@anblicks.com',
#  'jaydeep.panchal@anblicks.com',
#  'pathik.vora@anblicks.com',
#  'munwar@anblicks.com',
#  'abishek.kunduru@anblicks.com',
#  'lalitha.nasina@anblicks.com',
#  'dinesh.radadiya@anblicks.com',
#  'sandeep.nidumukkala@anblicks.com',
#  'pavankumar.vemula@anblicks.com',
#  'gaurav.patel@anblicks.com',
#  'geetanjali.dash@anblicks.com',
#  'wasimuddin.shaikh@anblicks.com',
#  'jhanvi.makwana@anblicks.com',
#  'bayya.vuragayala@anblicks.com',
#  'harshad.chhaiya@anblicks.com',
#  'ronak.parekh@anblicks.com',
#  'sajja.ratnasravya@anblicks.com',
#  'praveen@anblicks.com',
#  'vijay.diwakar@anblicks.com',
#  'sukhjeet.singh@anblicks.com',
#  'naveen.regula@anblicks.com',
#  'manish.gupta@anblicks.com',
#  'anand.maheshwari@anblicks.com',
#  'vinit.prajapati@anblicks.com',
#  'ankit.patel@anblicks.com',
#  'chitrang.modi@anblicks.com',
#  'siddhi.thakkar@anblicks.com',
#  'vinay.gundavaram@anblicks.com',
#  'parth.ghiya@anblicks.com',
#  'dilip.rajpurohit@anblicks.com',
#  'bhavin.bhavsar@anblicks.com',
#  'manish.shrivastav@anblicks.com',
#  'govind.singh@anblicks.com',
#  'jatin.patel@anblicks.com',
#  'dhruvi.sheladiya@anblicks.com',
#  'sandip.mehta@anblicks.com',
#  'priyank.patel@anblicks.com',
#  'mamta.prajapati@anblicks.com',
#  'farooq.md@anblicks.com',
#  'purvesh.kachhiya@anblicks.com',
#  'abhilash.p@anblicks.com',
#  'jayesh.prajapati@anblicks.com',
#  'nikunj.kasodariya@anblicks.com',
#  'tarun.patel@anblicks.com',
#  'chamundeswar.b@anblicks.com',
#  'shabbir.challawala@anblicks.com',
#  'vishal.sheladiya@anblicks.com',
#  'mohammad.dhanpurwala@anblicks.com',
#  'albert.manoj@anblicks.com',
#  'chintan.gajjar@anblicks.com',
#  'sudha.pattigudi@anblicks.com',
#  'esubabu.tibirisetti@anblicks.com',
#  'gnanasirisha.v@anblicks.com',
#  'vaibhavi.ghore@anblicks.com',
#  'raja.seeni@anblicks.com',
#  'rakesh.gupta@anblicks.com',
#  'nikhil.khasatiya@anblicks.com',
#  'satish.raghuwanshi@anblicks.com',
#  'mitesh.gajjar@anblicks.com',
#  'nagakumar.m@anblicks.com',
#  'bansilal.keloth@anblicks.com',
#  'jaydeep.munjapara@anblicks.com',
#  'nikunj.ranpura@anblicks.com',
#  'vipul.patel@anblicks.com',
#  'jaimin.patel@anblicks.com',
#  'ronak.padhya@anblicks.com',
#  'nilesh.jain@anblicks.com',
#  'hardik.sanghani@anblicks.com',
#  'yogesh.kumbhare@anblicks.com',
#  'kalyani.bhumireddy@anblicks.com',
#  'dileep.peddineni@anblicks.com',
#  'naveed.mf@anblicks.com',
#  'pooja.shah@anblicks.com',
#  'krunal.patel@anblicks.com',
#  'hemasri.edupuganti@anblicks.com',
#  'deepika.mudiyala@anblicks.com',
#  'jhansi.kandanathi@anblicks.com',
#  'pratham.vijayvargiya@anblicks.com',
#  'vicky.panwala@anblicks.com',
#  'chandni.patel@anblicks.com',
#  'santosh.yadav@anblicks.com',
#  'jyostna.jaladi@anblicks.com',
#  'maqboolahamed.momin@anblicks.com',
#  'hemant.nag@anblicks.com',
#  'prashanth.m@anblicks.com',
#  'chandrashekarreddy.genupula@anblicks.com',
#  'abhishek.makhija@anblicks.com',
#  'shivam.shah@anblicks.com',
#  'durgavikesh.pulapa@anblicks.com',
#  'kumar@anblicks.com',
#  'prasanna.alluri@anblicks.com',
#  'shalini.parisi@anblicks.com',
#  'vikas.karekannapla@anblicks.com',
#  'bharath.pogula@anblicks.com',
#  'kiran.kotha@anblicks.com',
#  'vishal.rami@anblicks.com',
#  'jignesh.gajjar@anblicks.com',
#  'satyapriya.mohanty@anblicks.com',
#  'uday.muppa@anblicks.com',
#  'ashish.shah@anblicks.com',
#  'krishnababu.chereddy@anblicks.com',
#  'sireesha.alavala@anblicks.com',
#  'nimesh.prajapati@anblicks.com',
#  'monal.patel@anblicks.com',
#  'arjun.g@anblicks.com',
#  'praveenkumar.macha@anblicks.com',
#  'rinku.gohel@anblicks.com',
#  'deval.kapadia@anblicks.com',
#  'omsai.kandregula@anblicks.com',
#  'fazal.babaria@anblicks.com',
#  'rithesh.gummerla@anblicks.com',
#  'shalinee.tawar@anblicks.com',
#  'khushbu.patel@anblicks.com',
#  'deep.santoki@anblicks.com',
#  'kuldeep.panchal@anblicks.com',
#  'sheetal.chandane@anblicks.com',
#  'muddasir.h@anblicks.com',
#  'hemal.patel@anblicks.com',
#  'munindra.ck@anblicks.com',
#  'pujitha.katuru@anblicks.com',
#  'janvi.bharadiya@anblicks.com',
#  'renu.kumari@anblicks.com',
#  'harsh.soni@anblicks.com',
#  'karthikeyan.jaganathan@anblicks.com',
#  'francis.mbunya@anblicks.com',
#  'venkatsai.erram@anblicks.com',
#  'nirva.sangani@anblicks.com',
#  'mansi.dobariya@anblicks.com',
#  'pinkesh.kothari@anblicks.com',
#  'mounika.mokkapati@anblicks.com',
#  'pavan.s@anblicks.com',
#  'chandrareddy.athmakur@anblicks.com',
#  'ganeshcharan.p@anblicks.com',
#  'manasa.jonnadula@anblicks.com',
#  'narayanarao.ponnam@anblicks.com',
#  'sumit.kumar@anblicks.com',
#  'anjaneyulu.m@anblicks.com',
#  'ish.lavingia@anblicks.com',
#  'swetha.cherukupalli@anblicks.com',
#  'krupal.khatri@anblicks.com',
#  'riddhi.patel@anblicks.com',
#  'raini.desai@anblicks.com',
#  'himanshu.rawani@anblicks.com',
#  'g.krishna@anblicks.com',
#  'miti.patel@anblicks.com',
#  'arkan.malek@anblicks.com',
#  'hitesh.tank@anblicks.com',
#  'saikiran.p@anblicks.com',
#  'mounika.koduru@anblicks.com',
#  'montej.shah@anblicks.com',
#  'arunkumar.k@anblicks.com',
#  'darshan.solanki@anblicks.com',
#  'jaitun.garish@anblicks.com',
#  'surender.thanneeru@anblicks.com',
#  'triveni.vemuri@anblicks.com',
#  'kiran.kumar@anblicks.com',
#  'tonu.varughese@anblicks.com',
#  'vraj.bhatt@anblicks.com',
#  'akhila.madduri@anblicks.com',
#  'divya.matsa@anblicks.com',
#  'keyur.ranpura@anblicks.com',
#  'jay.shukla@anblicks.com',
#  'jitendra.prajapat@anblicks.com',
#  'saeeda.rushnaiwala@anblicks.com',
#  'bhushan.sambhus@anblicks.com',
#  'nihal.singh@anblicks.com',
#  'rahul.singh@anblicks.com',
#  'nandini.thaker@anblicks.com',
#  'rohit.majithia@anblicks.com',
#  'ummehani@anblicks.com',
#  'killari.limbachiya@anblicks.com',
#  'shivanagarjuna.busi@anblicks.com',
#  'srikanth.yerramsetti@anblicks.com',
#  'keval.shah@anblicks.com',
#  'srisai.maddukuri@anblicks.com',
#  'manikumar.modela@anblicks.com',
#  'rehman.shaik@anblicks.com',
#  'utkarsh.dobariya@anblicks.com',
#  'uhapriya.akunuri@anblicks.com',
#  'sandhya.ravalavalasa@anblicks.com',
#  'sajeeda.shaik@anblicks.com',
#  'pavani.pasupulati@anblicks.com',
#  'rajasekharreddy.g@anblicks.com',
#  'hardik.gundigara@anblicks.com',
#  'ram.p@anblicks.com',
#  'neelesh.moravaneni@anblicks.com',
#  'procurement@anblicks.com',
#  'sravan.m@anblicks.com',
#  'sirisha.boppana@anblicks.com',
#  'jayapal.reddy@anblicks.com',
#  'rahul.ojha@anblicks.com',
#  'bharath.rudra@anblicks.com',
#  'mohammad.riyaz@anblicks.com',
#  'guruprasanna.muttu@anblicks.com',
#  'karthiga.pandian@anblicks.com',
#  'shruthi.gangam@anblicks.com',
#  'nidhi.kumari@anblicks.com',
#  'sapana.shah@anblicks.com',
#  'hardik.gohel@anblicks.com',
#  'dhaval.raval@anblicks.com',
#  'kalpesh.lohar@anblicks.com',
#  'pradhan@anblicks.com',
#  'satyachandu.pothuri@anblicks.com',
#  'sudharani.b@anblicks.com',
#  'aashutosh.makwana@anblicks.com',
#  'maulik.patel@anblicks.com',
#  'hrcommunique@anblicks.com',
#  'naresh.chillur@anblicks.com',
#  'harsh.patel@anblicks.com',
#  'sagar.katariya@anblicks.com',
#  'premalsinh.vaghela@anblicks.com',
#  'smit.patel@anblicks.com',
#  'drashti.shah@anblicks.com',
#  'rushika.shah@anblicks.com',
#  'narendra.boggavarapu@anblicks.com',
#  'vennela.sandu@anblicks.com',
#  'shravani.bathula@anblicks.com',
#  'manohar.gajengi@anblicks.com',
#  'vinaykumar.jorige@anblicks.com',
#  'saisrinivas.chinta@anblicks.com',
#  'himabindhu.ogirala@anblicks.com',
#  'chandana.kundeti@anblicks.com',
#  'parvathy.chintalapudi@anblicks.com',
#  'raviteja.baswa@anblicks.com',
#  'brahmeswara.donepudi@anblicks.com',
#  'sandhya.rayala@anblicks.com',
#  'manideep.bathini@anblicks.com',
#  'vishwanath.mittapalli@anblicks.com',
#  'deepthi.rayapati@anblicks.com',
#  'prapti.patel@anblicks.com',
#  'viha.dave@anblicks.com',
#  'gopala.kpayyavula@anblicks.com',
#  'seshagiri.sattiraju@anblicks.com',
#  'srikanth.manduri@anblicks.com',
#  'karan.chauhan@anblicks.com',
#  'venkateswarareddy.t@anblicks.com',
#  'vijay.makwana@anblicks.com',
#  'venkatapavan.y@anblicks.com',
#  'saiyam.bhupatawat@anblicks.com',
#  'sarita.rai@anblicks.com',
#  'anand.gangapuram@anblicks.com',
#  'krunal.rami@anblicks.com',
#  'naveen.pasupuleti@anblicks.com',
#  'lakhan.unadkat@anblicks.com',
#  'tanvir.diwan@anblicks.com',
#  'raj.sindal@anblicks.com',
#  'vijay.maruti@anblicks.com',
#  'kamlesh.bhatt@anblicks.com',
#  'lakshmi.potharaju@anblicks.com',
#  'santhosh.j@anblicks.com',
#  'saibharath.maradani@anblicks.com',
#  'devaraj.lanka@anblicks.com',
#  'saikrishna.c@anblicks.com',
#  'nishit.thacker@anblicks.com',
#  'reshma.banu@anblicks.com',
#  'paras.dave@anblicks.com',
#  'shubhangi.solanki@anblicks.com',
#  'swathi.dubbaku@anblicks.com',
#  'pushpendar.marri@anblicks.com',
#  'ronak.savani@anblicks.com',
#  'vrund.patel@anblicks.com',
#  'akshat.patel@anblicks.com',
#  'kricy.gundarania@anblicks.com',
#  'bhagyesh.bhut@anblicks.com',
#  'akshar.bhalodia@anblicks.com',
#  'poojaba.jadeja@anblicks.com',
#  'jay.aghera@anblicks.com',
#  'kishan.chanchad@anblicks.com',
#  'jolin.makwana@anblicks.com',
#  'hemangini.ninama@anblicks.com',
#  'tvng.durgapavan@anblicks.com',
#  'kalyani.dasari@anblicks.com',
#  'harsha.panchagnula@anblicks.com',
#  'pavankumar.sanepalli@anblicks.com',
#  'Srirama.narayana@anblicks.com',
#  'anusha.nandam@anblicks.com',
#  'yasaswipriya.sobila@anblicks.com',
#  'ankitha.chigurupati@anblicks.com',
#  'vasavi.indirala@anblicks.com',
#  'anandvardhan.pandi@anblicks.com',
#  'nagendra.sureddi@anblicks.com',
#  'yash.shah@anblicks.com',
#  'ketul.sharma@anblicks.com',
#  'gayathri.arepalli@anblicks.com',
#  'jayaram.bande@anblicks.com',
#  'vrushang.parikh@anblicks.com',
#  'imran.shaik@anblicks.com',
#  'yashkumar.patel@anblicks.com',
#  'surendra.sanayapalli@anblicks.com',
#  'raghava.kalli@anblicks.com',
#  'anil.bitra@anblicks.com',
#  'dharam.rajvadiya@anblicks.com',
#  'vijaybabu.kokku@anblicks.com',
#  'bhagya.talabattula@anblicks.com',
#  'riya.anadani@anblicks.com',
#  'mansuri.avesh@anblicks.com',
#  'kavisha.sutaria@anblicks.com',
#  'jagadeeshwar.k@anblicks.com',
#  'bhavana.vunyala@anblicks.com',
#  'saisyam.dampuri@anblicks.com',
#  'nagaarvind.adari@anblicks.com',
#  'raihan.mohammed@anblicks.com',
#  'jacqueline.a@anblicks.com',
#  'saikiran.nagarjuna@anblicks.com',
#  'venkatesh.mamidala@anblicks.com',
#  'shivaram.mamidi@anblicks.com',
#  'ganesh.neelakanta@anblicks.com',
#  'yeshmitha.karangula@anblicks.com',
#  'shiv.patel@anblicks.com',
#  'sravya.kommula@anblicks.com',
#  'jenis.gohil@anblicks.com',
#  'karthik.challagonda@anblicks.com',
#  'srihitha.cherlapally@anblicks.com',
#  'lokeshwar.chankapure@anblicks.com',
#  'nohitha.mongali@anblicks.com',
#  'sowbhagya.vodal@anblicks.com',
#  'sai.devabhakthuni@anblicks.com',
#  'varshitha.eddula@anblicks.com',
#  'giridhar.kompally@anblicks.com',
#  'shiva.nallavelli@anblicks.com',
#  'saicharan.madikonda@anblicks.com',
#  'ankit.amin@anblicks.com',
#  'yeshwanth.saikam@anblicks.com',
#  'pranaya.lingallu@anblicks.com',
#  'akshitha.veesam@anblicks.com',
#  'hari.mangali@anblicks.com',
#  'rahul.varakala@anblicks.com',
#  'sravani.sammu@anblicks.com',
#  'tejaswini.kolla@anblicks.com',
#  'ashritha.kanukula@anblicks.com',
#  'ramateja.damireddy@anblicks.com',
#  'saisurya.hanumanthu@anblicks.com',
#  'krishna.chaurasia@anblicks.com',
#  'sainanditha.t@anblicks.com',
#  'srinivas.eraboena@anblicks.com',
#  'debrup.paul@anblicks.com',
#  'saravana.murugesh@anblicks.com',
#  'neha.dasari@anblicks.com',
#  'anil.bariki@anblicks.com',
#  'bharati.kandukuri@anblicks.com',
#  'vasanth.kandagatla@anblicks.com',
#  'nazmanaz.sheik@anblicks.com',
#  'mounika.masuram@anblicks.com',
#  'test.everyone@anblicks.com',
#  'harsha.nadendla@anblicks.com',
#  'haribabu.thamatam@anblicks.com',
#  'nehith.bandari@anblicks.com',
#  'abhinav.chelluri@anblicks.com',
#  'ashok.eeday@anblicks.com',
#  'anvesh.karre@anblicks.com',
#  'raviram.karra@anblicks.com',
#  'avinash.chinta@anblicks.com',
#  'yaswanth.yerasi@anblicks.com',
#  'swapna.boda@anblicks.com',
#  'kranthi.devalapalli@anblicks.com',
#  'ramesh.talamala@anblicks.com',
#  'kowsalya.kambala@anblicks.com',
#  'sareen.banu@anblicks.com',
#  'robert.alvarez@anblicks.com',
#  'selina.tanha@anblicks.com',
#  'mdshahinoor.alam@anblicks.com',
#  'srikanth.chirukonda@anblicks.com',
#  'pradeep.kotamgari@anblicks.com',
#  'utsav.patel@anblicks.com',
#  'sobhan.samantaray@anblicks.com',
#  'syamsundar.gudibandi@anblicks.com',
#  'faiyaz.maru@anblicks.com',
#  'sreedhar@anblicks.com',
#  'pravallika.korrapati@anblicks.com',
#  'pavan.muniganti@anblicks.com',
#  'vijay.janagam@anblicks.com',
#  'brahmaiah.vallabhuni@anblicks.com',
#  'dhaval.mayur@anblicks.com',
#  'srilakshmi.gadupudi@anblicks.com',
#  'venkat.pilli@anblicks.com',
#  'nani.bonela@anblicks.com',
#  'vinay.potu@anblicks.com',
#  'ramya.anumukonda@anblicks.com',
#  'akhila.siripurapu@anblicks.com',
#  'nitya.sripati@anblicks.com',
#  'thikson.tivakar@anblicks.com',
#  'vishvak.tatineni@anblicks.com',
#  'lance.lugo@datalinksoftware.com',
#  'svinod@asc-es.com',
#  'bharath.sudini@anblicks.com',
#  'Kamal.jasuja@anblicks.com',
#  'bharatsinh.parmar@anblicks.com',
#  'madhumitha.kuna@anblicks.com',
#  'dasaradharamaiah.k@anblicks.com',
#  'annual.event@anblicks.com',
#  'pavan.sirasanambedu@anblicks.com',
#  'savan.parmar@anblicks.com',
#  'vamshi.tumu@anblicks.com',
#  'sreeni.gandluru@anblicks.com',
#  'satya.brundavanam@anblicks.com',
#  'srilatha.kallagunta@anblicks.com',
#  'musalaiah.pemmadi@anblicks.com',
#  'vikranth.putta@anblicks.com',
#  'ashok.mallepalle@anblicks.com',
#  'pavan.telanakula@anblicks.com',
#  'venkat.gorrepati@anblicks.com',
#  'ramesh.dande@anblicks.com',
#  'dinesh.chamarthi@anblicks.com',
#  'saikiran.samudrala@anblicks.com',
#  'twinkal.patel@anblicks.com',
#  'venkataram.thadi@anblicks.com',
#  'senthil.kumar@anblicks.com',
#  'bhumika.adhia@anblicks.com',
#  'chaitanya@anblicks.com',
#  'yaswanth.nimmala@anblicks.com',
#  'veena.kummari@anblicks.com',
#  'thilak.jayachandran@anblicks.com',
#  'praveen.garlapati@anblicks.com',
#  'staton.deshazo@anblicks.com',
#  'stuti.adhvaryu@anblicks.com',
#  'ashish.patel@anblicks.com',
#  'megha.sangani@anblicks.com',
#  'cheera.kumar@anblicks.com',
#  'uday.navadasari@anblicks.com',
#  'manohar.madishetty@anblicks.com',
#  'lavina.rego@anblicks.com',
#  'senthil.pandurangan@anblicks.com',
#  'naresh.mallepalli@anblicks.com',
#  'suman.ghimire@anblicks.com',
#  'prasanna.anthati@anblicks.com',
#  'Anil.Makineni@datalinksoftware.com',
#  'krishna.manchikanti@anblicks.com',
#  'bhargava.buchipally@anblicks.com',
#  'indrakanth.chidara@anblicks.com',
#  'sirisha.bobba@anblicks.com',
#  'omprakash.gurram@anblicks.com',
#  'anubhav.rai@anblicks.com',
#  'brijesh.amrutiya@anblicks.com',
#  'sudha.papasani@anblicks.com',
#  'sreedhar.yerragunta@anblicks.com',
#  'smriti.das@anblicks.com',
#  'anushree.mahajan@anblicks.com',
#  'vinay.chitrakathi@anblicks.com',
#  'dharmik.solanki@anblicks.com',
#  'amij.patel@anblicks.com',
#  'aayushi.soni@anblicks.com',
#  'madhu@anblicks.com',
#  'abhishek.singh@anblicks.com',
#  'amit@anblicks.com',
#  'gowtham.voruganti@anblicks.com',
#  'samir.bhatt@anblicks.com',
#  'munwar@anblicks.com',
#  'abishek.kunduru@anblicks.com',
#  'geetanjali.dash@anblicks.com',
#  'abhilash.p@anblicks.com',
#  'nilesh.jain@anblicks.com',
#  'abhishek.makhija@anblicks.com',
#  'kumar@anblicks.com',
#  'bharath.pogula@anblicks.com',
#  'ashish.shah@anblicks.com',
#  'muddasir.h@anblicks.com',
#  'miti.patel@anblicks.com',
#  'rajasekharreddy.g@anblicks.com',
#  'hardik.gundigara@anblicks.com',
#  'shruthi.gangam@anblicks.com',
#  'sudharani.b@anblicks.com',
#  'smit.patel@anblicks.com',
#  'srikanth.manduri@anblicks.com',
#  'anand.gangapuram@anblicks.com',
#  'ramateja.damireddy@anblicks.com',
#  'vishvak.tatineni@anblicks.com',
#  'ramesh.dande@anblicks.com',
#  'fuad.nour@anblicks.com',
#  'ip-service@anblicks.com',
#  'pradeep.kollu@anblicks.com',
#  'shani.jangid@anblicks.com',
#  'sumera.jaggi@anblicks.com']

# %%
print(email)
# Out:
# ['dhamodharan.balamani@anblicks.com', 'nishant.shah@anblicks.com', 'devang.patel@anblicks.com', 'manoj.kumar@anblicks.com', 'gowtham.voruganti@anblicks.com', 'pranshu.joshi@anblicks.com', 'kotapati.saitha@anblicks.com', 'rasi.konatham@anblicks.com', 'samir.bhatt@anblicks.com', 'munwar@anblicks.com', 'abishek.kunduru@anblicks.com', 'lalitha.nasina@anblicks.com', 'sandeep.nidumukkala@anblicks.com', 'gaurav.patel@anblicks.com', 'geetanjali.dash@anblicks.com', 'sajja.ratnasravya@anblicks.com', 'vijay.diwakar@anblicks.com', 'ankit.patel@anblicks.com', 'vinay.gundavaram@anblicks.com', 'purvesh.kachhiya@anblicks.com', 'abhilash.p@anblicks.com', 'raja.seeni@anblicks.com', 'mitesh.gajjar@anblicks.com', 'bansilal.keloth@anblicks.com', 'nikunj.ranpura@anblicks.com', 'jaimin.patel@anblicks.com', 'ronak.padhya@anblicks.com', 'nilesh.jain@anblicks.com', 'hardik.sanghani@anblicks.com', 'deepika.mudiyala@anblicks.com', 'santosh.yadav@anblicks.com', 'abhishek.makhija@anblicks.com', 'durgavikesh.pulapa@anblicks.com', 'sireesha.alavala@anblicks.com', 'praveenkumar.macha@anblicks.com', 'rithesh.gummerla@anblicks.com', 'ganeshcharan.p@anblicks.com', 'manasa.jonnadula@anblicks.com', 'saikiran.p@anblicks.com', 'mounika.koduru@anblicks.com', 'surender.thanneeru@anblicks.com', 'kiran.kumar@anblicks.com', 'akhila.madduri@anblicks.com', 'divya.matsa@anblicks.com', 'saeeda.rushnaiwala@anblicks.com', 'srisai.maddukuri@anblicks.com', 'rehman.shaik@anblicks.com', 'uhapriya.akunuri@anblicks.com', 'pavani.pasupulati@anblicks.com', 'rajasekharreddy.g@anblicks.com', 'sravan.m@anblicks.com', 'rahul.ojha@anblicks.com', 'bharath.rudra@anblicks.com', 'dhaval.raval@anblicks.com', 'sudharani.b@anblicks.com', 'aashutosh.makwana@anblicks.com', 'naresh.chillur@anblicks.com', 'harsh.patel@anblicks.com', 'sagar.katariya@anblicks.com', 'rushika.shah@anblicks.com', 'shravani.bathula@anblicks.com', 'manohar.gajengi@anblicks.com', 'saisrinivas.chinta@anblicks.com', 'deepthi.rayapati@anblicks.com', 'prapti.patel@anblicks.com', 'vijay.makwana@anblicks.com', 'krunal.rami@anblicks.com', 'raj.sindal@anblicks.com', 'saisyam.dampuri@anblicks.com', 'nagaarvind.adari@anblicks.com', 'lokeshwar.chankapure@anblicks.com', 'shiva.nallavelli@anblicks.com', 'tejaswini.kolla@anblicks.com', 'vasanth.kandagatla@anblicks.com', 'harsha.nadendla@anblicks.com', 'haribabu.thamatam@anblicks.com', 'abhinav.chelluri@anblicks.com', 'ramesh.talamala@anblicks.com', 'pavan.muniganti@anblicks.com', 'akhila.siripurapu@anblicks.com', 'nitya.sripati@anblicks.com', 'vishvak.tatineni@anblicks.com', 'lance.lugo@datalinksoftware.com', 'madhumitha.kuna@anblicks.com', 'Vinay.Beeravolu@datalinksoftware.com', 'John.Hargett@datalinksoftware.com', 'Logan.Galler@datalinksoftware.com', 'Kenneth.Harper@datalinksoftware.com', 'chintan.mehta@anblicks.com', 'it@anblicks.com', '___@anblicks.onmicrosoft.com', 'aakansha.jain@anblicks.com', 'aashutosh.makwana@anblicks.com', 'aayushi.soni@anblicks.com', 'abhilash.p@anblicks.com', 'abhinav.chelluri@anblicks.com', 'abhinav.muvva@anblicks.com', 'abhishek.makhija@anblicks.com', 'abhishek.singh@anblicks.com', 'abhishek.vadnagra@anblicks.com', 'abishek.kunduru@anblicks.com', 'aditya.jain@anblicks.com', 'admin@anblicks.com', 'ahm.reception@anblicks.com', 'ajaychand.b@anblicks.com', 'saiakhil.gollamudi@anblicks.com', 'akhila.madduri@anblicks.com', 'akshar.bhalodia@anblicks.com', 'akshat.patel@anblicks.com', 'akshitha.veesam@anblicks.com', 'alan.parker@anblicks.com', 'albert.manoj@anblicks.com', 'alerts@anblicks.com', 'aman.dhillon@anblicks.com', 'amij.patel@anblicks.com', 'amit@anblicks.com', 'amit.maru@anblicks.com', 'amit.somaru@anblicks.com', 'anand.gangapuram@anblicks.com', 'anand.k@anblicks.com', 'anand.maheshwari@anblicks.com', 'anandvardhan.pandi@anblicks.com', 'ananth.thuluva@anblicks.com', 'Accounting@anblicks.com', 'anblicksdallas@anblicks.com', 'anblicks-HR@anblicks.com', 'aneneosa.isichei@anblicks.com', 'anil.bitra@anblicks.com', 'Anil.Makineni_DATALINKSOFTWARE.COM#EXT#@anblic ...

# %%
# %store email
# Out:
# Stored 'email' (list)

# %%
b=session.sql(f""" select (last_day_of_work) from {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_EMP_METADATA}""").collect()
b1=pd.DataFrame(b)

# %%
b1
# Out:
#     LAST_DAY_OF_WORK
# 0         2040-07-04
# 1         2040-07-04
# 2         2040-07-04
# 3         2040-07-04
# 4         2040-07-04
# ..               ...
# 700       2040-07-04
# 701       2040-07-04
# 702       2040-07-04
# 703       2040-07-04
# 704       2040-07-04
#
# [705 rows x 1 columns]

# %%
login=[]
count=0
for i in range(len(b1)):
    #print (a1['SESSION_USER'][i])
    count=count+1
    login.append(b1['LAST_DAY_OF_WORK'][i])
print(count)
# Out:
# 705

# %%
login
# Out:
# [datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 8, 21),
#  datetime.date(2040, 8, 17),
#  datetime.date(2040, 7, 24),
#  datetime.date(2040, 8, 3),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 7, 27),
#  datetime.date(2040, 8, 11),
#  datetime.date(2040, 8, 22),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 8, 8),
#  datetime.date(2040, 8, 8),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 8, 21),
#  datetime.date(2040, 8, 14),
#  datetime.date(2040, 8, 24),
#  datetime.date(2040, 7, 6),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 8, 14),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 7, 25),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 8, 23),
#  datetime.date(2040, 7, 20),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 8, 2),
#  datetime.date(2040, 8, 27),
#  datetime.date(2040, 8, 27),
#  datetime.date(2040, 8, 24),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 8, 14),
#  datetime.date(2040, 8, 28),
#  datetime.date(2040, 8, 22),
#  datetime.date(2040, 8, 22),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 8, 14),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 8, 12),
#  datetime.date(2040, 8, 22),
#  datetime.date(2040, 7, 18),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 7, 11),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 8, 16),
#  datetime.date(2040, 8, 3),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 7, 24),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 8, 23),
#  datetime.date(2040, 7, 11),
#  datetime.date(2040, 8, 23),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 8, 7),
#  datetime.date(2040, 6, 29),
#  datetime.date(2040, 8, 22),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 8, 9),
#  datetime.date(2040, 7, 21),
#  datetime.date(2040, 6, 27),
#  datetime.date(2040, 8, 4),
#  datetime.date(2040, 8, 4),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 26),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 8, 16),
#  datetime.date(2040, 8, 4),
#  datetime.date(2040, 8, 25),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 6, 21),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 7, 24),
#  datetime.date(2040, 8, 2),
#  datetime.date(2040, 8, 10),
#  datetime.date(2040, 8, 17),
#  datetime.date(2040, 6, 22),
#  datetime.date(2040, 8, 22),
#  datetime.date(2040, 8, 2),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4),
#  datetime.date(2040, 7, 4)]

# %%
print(login)
# Out:
# [datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 7, 4), datetime.date(2040, 6, 21), datetime.date(2040, 8, 21), datetime.date(2040, 8, 17), datetime.date(2040, 7, 24), datetime.date(2040, 8, 3), datetime.date(2040, 6, 22), datetime.date(2040, 6, 22), datetime.date(2040, 6, 22), datetime.date(2040, 7, 27), datetime.date(2040, 8, 11), datetime.date(2040, 8, 22), datetime.date(2040, 6, 22), datetime.date(2040, 6, 21), datetime.date(2040, 6, 21), datetime.date(2040, 6, 22), datetime.date(2040, 8, 8), datetime.date(2040, 8, 8), datetime.date(2040, 6, 22), datetime.date(2040, 8, 21), datetime.date(2040, 8, 14), datetime.date(2040, 8, 24), datetime.date(2040, 7, 6), datetime.date(2040, 6, 21), datetime.date(2040, 6, 21), datetime.date(2040, 6, 22), datetime.date(2040, 8, 14), datetime.date(2040, 6, 22), datetime.date(2040, 6, 21), datetime.date(2040, 6, 22), datetime.date(2040, 7, 25), datetime.date(2040, 6, 22), datetime.date(2040, 8, 23), datetime.date(2040, 7, 20), datetime.date(2040, 6, 21), datetime.date(2040, 6, 21), datetime.date(2040, 6, 21), datetime.date(2040, 8, 2), datetime.date(2040, 8, 27), datetime.date(2040, 8, 27), datetime.date(2040, 8, 24), datetime.date(2040, 6, 22), datetime.date(2040, 6, 22), datetime.date(2040, 8, 14), datetime.date(2040, 8, 28), datetime.date(2040, 8, 22), datetime.date(2040, 8, 22), datetime.date(2040, 6, 21), datetime.date(2040, 6, 22), datetime.date(2040, 8, 14), datetime.date(2040, 6, 21), datetime.date(2040, 8, 12), datetime.date(2040, 8, 22), datetime.date(2040, 7, 18), datetime.date(2040, 6, 21), datetime.date(2040, 6, 22), datetime.date(2040, 7, 11), dateti ...

# %%
# %store login
# Out:
# Stored 'login' (list)

# %%
#my code
import pandas as pd

d=session.sql(f""" select SNAPSHOT_DATETIME from {SNOWPATROL_DB}.{DEVOPS_SH}.{TBL_OKTA_USERS}""").collect()
d1=pd.DataFrame(d)

# %%
d1
# Out:
#     SNAPSHOT_DATETIME
# 0          2023-06-09
# 1          2023-08-27
# 2          2023-08-25
# 3          2023-08-07
# 4          2023-08-18
# ..                ...
# 700        2023-08-10
# 701        2023-08-17
# 702        2023-06-22
# 703        2023-08-22
# 704        2023-08-02
#
# [705 rows x 1 columns]

# %%
Order_Date=[]
count=0
for i in range(len(d1)):
    #print (a1['SESSION_USER'][i])
    count=count+1
    Order_Date.append(d1['SNAPSHOT_DATETIME'][i])
print(count)
# Out:
# 705

# %%
print(Order_Date)
# Out:
# [datetime.date(2023, 6, 9), datetime.date(2023, 8, 27), datetime.date(2023, 8, 25), datetime.date(2023, 8, 7), datetime.date(2023, 8, 18), datetime.date(2023, 8, 17), datetime.date(2023, 3, 26), datetime.date(2023, 8, 23), datetime.date(2023, 5, 10), datetime.date(2023, 8, 10), datetime.date(2023, 7, 16), datetime.date(2023, 8, 1), datetime.date(2021, 12, 31), datetime.date(2023, 7, 2), datetime.date(2022, 8, 17), datetime.date(2023, 8, 23), datetime.date(2023, 2, 24), datetime.date(2023, 8, 16), datetime.date(2023, 8, 21), datetime.date(2023, 8, 25), datetime.date(2023, 8, 24), datetime.date(2022, 2, 7), datetime.date(2023, 7, 3), datetime.date(2023, 7, 3), datetime.date(2023, 8, 22), datetime.date(2023, 8, 24), datetime.date(2023, 8, 17), datetime.date(2023, 7, 27), datetime.date(2023, 8, 21), datetime.date(2023, 6, 15), datetime.date(2023, 8, 16), datetime.date(2021, 12, 31), datetime.date(2023, 3, 7), datetime.date(2023, 8, 23), datetime.date(2023, 7, 21), datetime.date(2023, 8, 26), datetime.date(2023, 8, 27), datetime.date(2023, 8, 24), datetime.date(2023, 8, 8), datetime.date(2023, 8, 21), datetime.date(2023, 8, 27), datetime.date(2023, 8, 24), datetime.date(2023, 5, 24), datetime.date(2023, 6, 20), datetime.date(2023, 7, 7), datetime.date(2023, 8, 4), datetime.date(2023, 6, 18), datetime.date(2023, 8, 12), datetime.date(2023, 8, 22), datetime.date(2023, 8, 17), datetime.date(2023, 7, 5), datetime.date(2023, 7, 27), datetime.date(2023, 7, 23), datetime.date(2023, 7, 5), datetime.date(2023, 7, 31), datetime.date(2023, 2, 27), datetime.date(2023, 6, 14), datetime.date(2023, 8, 27), datetime.date(2023, 8, 11), datetime.date(2023, 5, 14), datetime.date(2023, 7, 31), datetime.date(2022, 8, 10), datetime.date(2023, 8, 15), datetime.date(2023, 8, 1), datetime.date(2023, 8, 25), datetime.date(2023, 8, 25), datetime.date(2023, 8, 8), datetime.date(2023, 7, 7), datetime.date(2023, 5, 1), datetime.date(2023, 8, 24), datetime.date(2023, 8, 12), datetime.date(2023, 6, 8), datetime.date(2023, 7, 2), datetime.date(2023, 6, 27), datetime.date(2023, 8, 16), datetime.date(2023, 8, 27), datetime.date(2023, 3, 2), datetime.date(2023, 8, 1), datetime.date(2023, 8, 17), datetime.date(2023, 8, 23), datetime.date(2023, 7, 24), datetime.date(2023, 6, 6), datetime.date(2023, 8, 27), datetime.date(2023, 6, 28), datetime.date(2023, 6, 14), datetime.date(2023, 8, 22), datetime.date(2023, 8, 25), datetime.date(2023, 6, 7), datetime.date(2023, 8, 25), datetime.date(2022, 6, 30), datetime.date(2023, 6, 28), datetime.date(2023, 4, 12), datetime.date(2023, 7, 17), datetime.date(2023, 8, 10), datetime.date(2022, 11, 22), datetime.date(2023, 8, 20), datetime.date(2023, 8, 3), datetime.date(2023, 5, 25), datetime.date(2023, 5, 29), datetime.date(2023, 2, 8), datetime.date(2023, 8, 4), datetime.date(2023, 7, 11), datetime.date(2023, 7, 11), datetime.date(2023, 7, 20), datetime.date(2023, 7, 28), datetime.date(2023, 8, 23), datetime.date(2022, 8, 4), datetime.date(2023, 4, 14), datetime.date(2023, 8, 9), datetime.date(2023, 8, 21), datetime.date(2023, 8, 23), datetime.date(2023, 8, 21), datetime.date(2023, 8, 26), datetime.date(2023, 7, 24), datetime.date(2023, 8, 3), datetime.date(2022, 8, 25), datetime.date(2023, 6, 21), datetime.date(2023, 8, 25), datetime.date(2023, 8, 9), datetime.date(2023, 8, 5), datetime.date(2023, 8, 18), datetime.date(2023, 7, 4), datetime.date(2023, 8, 21), datetime.date(2023, 8, 20), datetime.date(2023, 8, 8), datetime.date(2022, 7, 5), datetime.date(2023, 7, 13), datetime.date(2023, 8, 23), datetime.date(2023, 7, 10), datetime.date(2023, 8, 11), datetime.date(2023, 7, 23), datetime.date(2023, 8, 26), datetime.date(2022, 12, 29), datetime.date(2022, 6, 30), datetime.date(2023, 8, 21), datetime.date(2023, 8, 26), datetime.date(2023, 8, 26), datetime.date(2023, 8, 24), datetime.date(2023, 8, 19), datetime.date(2023, 8, 25), datetime.date(2023, 4, 13), datetime.date(2023, 8, 25), datetime.date(2023, 6, 8), datetime.date(2023, 6, 19) ...

# %%
import pandas as pd

# %%
d1["SNAPSHOT_DATETIME"] = pd.to_datetime(d1["SNAPSHOT_DATETIME"])

startDate = pd.to_datetime(d1["SNAPSHOT_DATETIME"]).min()

endDate = pd.to_datetime(d1["SNAPSHOT_DATETIME"]).max()

# %%
startDate
# Out:
# Timestamp('2021-12-01 00:00:00')

# %%
endDate
# Out:
# Timestamp('2023-08-28 00:00:00')

# %% [markdown]
# ### Local utility functions

# %%
session.sql("use database DEVOPS_SH")

# %%
session.udf.register_from_file(
      file_path="train1.py"
      , func_name="contains_anyof"
      , name=f"{SNOWPATROL_DB}.{DEVOPS_SH}.udf_contains_anyof"
      , is_permanent=True
      , packages = ["snowflake-snowpark-python"]
      , imports=[f"@{SNOWPATROL_DB}.{DEVOPS_SH}.{DEPS_STAGE}/constants1.py"]
      , stage_location=f"{SNOWPATROL_DB}.{DEVOPS_SH}.{OBJECT_STAGE}"
      , replace=True
)

# %% [markdown]
# ### Model Training

# %%
session.sproc.register_from_file(
    file_path = f"@{SNOWPATROL_DB}.{DEVOPS_SH}.{DEPS_STAGE}/train1.py"
    ,func_name = "run_model_today"
    ,name=f"{SNOWPATROL_DB}.{DEVOPS_SH}.run_model_today"
    ,input_types=[T.IntegerType(),T.IntegerType(),T.FloatType(),T.BooleanType(),T.BooleanType(),T.BooleanType(), T.BooleanType()]
    ,return_type=T.VariantType()
    ,is_permanent=True
    ,replace=True
    ,stage_location=f"@{SNOWPATROL_DB}.{DEVOPS_SH}.{OBJECT_STAGE}"
    ,packages=['snowflake-snowpark-python','pandas','scikit-learn==1.2.1','joblib==1.1.1', 'numpy']
    ,imports=[f"@{SNOWPATROL_DB}.{DEVOPS_SH}.{DEPS_STAGE}/constants1.py"]
)
# Out:
# Package 'scikit-learn' is not installed in the local environment. Your UDF might not work when the package is installed on the server but not on your local environment.
# Package 'joblib' is not installed in the local environment. Your UDF might not work when the package is installed on the server but not on your local environment.

# %% [markdown]
# ## License usage probablity prediction with revocation decision
# Local trigger

# %%
# %%time
# from train1 import run_model_today
# results = session.call('run_model_today', 1,45,0.5,False,False)
# display(results)

# %%
# license_prediction_feature_set = session.table(f"{SNOWPATROL_DB}.{SNOWPATROL_SCHEMA}.license_prediction_feature_set")
# license_usage_probability = license_prediction_feature_set.select(
#     F.col("session_user")
#     , F.col("title")
#     , F.col("department")
#     , F.col("division")
#     , F.col("work_days_since_last_login")
#     ,F.col("training_date").alias("model_trained_on")
#     ,F.col("cutoff_date")
#     , F.call_udf(f"{SNOWPATROL_DB}.{SNOWPATROL_SCHEMA}.udf_predict_login_probability", *[F.col(c) for c in ["weighted_authentications_per_day","work_days_since_last_login", 'authentications_per_day', 'log_work_days_since_last_login']]).alias("probability_no_login")
# )
# license_revocation_decision = license_usage_probability.with_column("revoke_access", F.iff(F.col("probability_no_login") > 0.5, 1, 0))

# license_revocation_decision.write.mode("overwrite").save_as_table(f"{SNOWPATROL_DB}.{SNOWPATROL_SCHEMA}.license_revocation_decision")
